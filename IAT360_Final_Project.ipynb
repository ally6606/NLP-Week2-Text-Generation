# %% [markdown]
# <a href="https://colab.research.google.com/github/ally6606/NLP-Week2-Text-Generation/blob/main/IAT360_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wilmington Restaurant Recommendation Chatbot
# ## Introduction

# %% [markdown]
# # Install Dependencies

# %%
# !pip3 install transformers sentence-transformers -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %% [markdown]
# # Import Libraries

# %%
from transformers import pipeline
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np

# %%
llm = pipeline('text2text-generation', model='google/flan-t5-base')
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %% [markdown]
# ## Prepare a Dataset

# %%
# === 1. Set file paths (change to your actual paths) ===
business_path = "C:/Users/User/Desktop/yelp_dataset/yelp_academic_dataset_business.json"
review_path = "C:/Users/User/Desktop/yelp_dataset/yelp_academic_dataset_review.json"
output_csv_path = "yelp_business_reviews_combined.csv"

# === 2. Load JSONL files (one JSON object per line) ===
print("Loading business.json...")
business_df = pd.read_json(business_path, lines=True)

print("Loading review.json...")
review_df = pd.read_json(review_path, lines=True)

print("Business rows:", len(business_df))
print("Review rows:", len(review_df))

# === 3. (Optional) keep only useful columns from business ===
business_cols_to_keep = [
    "business_id",
    "name",
    "address",
    "city",
    "state",
    "postal_code",
    "latitude",
    "longitude",
    "stars",          # average rating of the business
    "review_count",
    "is_open",
    "categories",
    "hours",
]

business_small = business_df[business_cols_to_keep]

# === 4. Merge reviews with business info on business_id ===
print("Merging review and business data...")
merged_df = review_df.merge(business_small, on="business_id", how="inner")

print("Merged rows:", len(merged_df))

# === 5. (Optional) reduce columns for RAG-ready CSV ===
rag_cols = [
    "review_id",
    "user_id",
    "business_id",
    "name",          # business name (good as a "title")
    "address",
    "city",
    "state",
    "postal_code",
    "categories",
    "stars_x",       # review rating
    "stars_y",       # business average rating
    "text",          # review text (main content for RAG)
    "date",
    "useful",
    "funny",
    "cool",
]

# rename for clarity in output
merged_df = merged_df[rag_cols].rename(
    columns={
        "stars_x": "review_stars",
        "stars_y": "business_stars",
    }
)

# === 6. Save to CSV ===
print(f"Saving combined CSV to: {output_csv_path}")
merged_df.to_csv(output_csv_path, index=False)

print("Done! CSV ready for RAG chatbot.")

# %% [markdown]
# ## Generate Dense Embeddings and Build an Index

# %%
# Load CSV

csv_path = "C:/Users/User/Desktop/yelp_rag_ready.csv"
print("Loading dataset...")

df = pd.read_csv(csv_path)

print(f"Loaded rows: {len(df)}")
df.head()
# Out:
# Loading dataset...
# Loaded rows: 6990280
#               business_id  review_stars  \
# 0  XQfwVwDr-v0ZS3_CbbE5Xw             3
# 1  7ATYjTIgM3jUlt4UM3IypQ             5
# 2  YjUWPpI6HXG530lwP-fb2A             3
# 3  kxX2SOes4o-D3ZQBkiMRfA             5
# 4  e4Vwtrqf-wpJfwesgvdgxQ             4
#
#                                                 text  useful  funny  cool  \
# 0  If you decide to eat here, just be aware it is...       0      0     0
# 1  I've taken a lot of spin classes over the year...       1      0     1
# 2  Family diner. Had the buffet. Eclectic assortm...       0      0     0
# 3  Wow!  Yummy, different,  delicious.   Our favo...       1      0     1
# 4  Cute interior and owner (?) gave us tour of up...       1      0     1
#
#                            name                   address          city state  \
# 0  Turning Point of North Wales       1460 Bethlehem Pike   North Wales    PA
# 1    Body Cycle Spinning Studio  1923 Chestnut St, 2nd Fl  Philadelphia    PA
# 2             Kettle Restaurant     748 W Starr Pass Blvd        Tucson    AZ
# 3                         Zaika            2481 Grant Ave  Philadelphia    PA
# 4                          Melt             2549 Banks St   New Orleans    LA
#
#    review_count  business_stars  \
# 0           169             3.0
# 1           144             5.0
# 2            47             3.5
# 3           181             4.0
# 4            32             4.0
#
#                                           categories
# 0  Restaurants, Breakfast & Brunch, Food, Juice B...
# 1  Active Life, Cycling Classes, Trainers, Gyms, ...
# 2                    Restaurants, Breakfast & Brunch
# 3              Halal, Pakistani, Restaurants, Indian
# 4  Sandwiches, Beer, Wine & Spirits, Bars, Food, ...

# %%
print(f"Total rows loaded: {len(df)}")
print("="*60)

# Show unique cities

print("🔹 Unique City Names (first 50 shown):")
unique_cities = df["city"].dropna().unique()

print(f"Total number of unique cities: {len(unique_cities)}")
print(unique_cities[:50])   # preview
print("="*60)

# Show the number of reviews per city, we chose a review side that is suitable for this project scope

print("🔹 Review Counts per City (Top 20):")
city_counts = df["city"].value_counts()

print(city_counts.head(20))
print("="*60)
# Out:
# Total rows loaded: 6990280
# ============================================================
# 🔹 Unique City Names (first 50 shown):
# Total number of unique cities: 1416
# ['North Wales' 'Philadelphia' 'Tucson' 'New Orleans' 'Quakertown'
#  'Santa Barbara' 'Tampa' 'Indianapolis' 'St Louis' 'Saint Louis' 'Carmel'
#  'Carpinteria' 'Speedway' 'Phoenixville' 'Broomall' 'Nashville'
#  'Eddystone' 'Goleta' 'Norristown' 'Reno' 'Lutz' 'Port Richey' 'Edmonton'
#  'Penns Grove' 'Granite City' 'Meridian' 'Clearwater' 'Florissant'
#  'Kenner' 'Willow Grove' 'Land O Lakes' 'Boise' 'Bensalem' 'Manchester'
#  'West Chester' 'Fishers' 'Safety Harbor' 'Metairie' 'Sparks'
#  'Saint Petersburg' 'Deptford' 'Malvern' 'Garden City' 'Mt. Laurel'
#  'Newtown' 'Brookhaven' 'Riverview' 'Hermitage' 'Bryn Mawr' 'Springfield']
# ============================================================
# 🔹 Review Counts per City (Top 20):
# city
# Philadelphia        967552
# New Orleans         635364
# Tampa               454889
# Nashville           451571
# Tucson              404880
# Indianapolis        361489
# Reno                351573
# Santa Barbara       269630
# Saint Louis         253437
# Boise               105366
# Edmonton            101823
# Clearwater           87442
# Saint Petersburg     78907
# Sparks               73033
# Metairie             64361
# St. Louis            63451
# Franklin             56783
# St. Petersburg       54480
# Goleta               45643
# Wilmington           44814
# Name: count, dtype: int64
# ============================================================

# %%
# Filter for Wilmington

df_wilmington = df[df["city"].str.contains("Wilmington", case=False, na=False)].copy()

# Remove rows with empty review text
df_wilmington = df_wilmington.dropna(subset=["text"])
df_wilmington = df_wilmington[df_wilmington["text"].str.strip() != ""]

print("Total Wilmington rows (all categories):", len(df_wilmington))


# Filter Wilmington restaurants only, remove all other business

restaurant_pattern = r"Restaurant|Food|Diner|Cafe|Pizza|Bar|Brewery|Pub|Bakery"

df_wilmington_restaurants = df_wilmington[
    df_wilmington["categories"].str.contains(restaurant_pattern, case=False, na=False)
].copy()

print("Wilmington restaurant rows:", len(df_wilmington_restaurants))


# Create embeddings for restaurant reviews only

embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

documents = df_wilmington_restaurants["text"].tolist()

embeddings_wilmington = embedding_model.encode(
    documents,
    batch_size=64,
    show_progress_bar=True
)

# Attach embeddings to file
df_wilmington_restaurants["embedding"] = embeddings_wilmington.tolist()


# Save the result

df_wilmington_restaurants.to_pickle("yelp_wilmington_restaurants_with_embeddings.pkl")

print("Saved Wilmington RESTAURANT subset with new embeddings.")
# Out:
# Total Wilmington rows (all categories): 44978
# Wilmington restaurant rows: 34791
# Batches:   0%|          | 0/544 [00:00<?, ?it/s]
# Saved Wilmington RESTAURANT subset with new embeddings.

# %%
df_w = pd.read_pickle("yelp_wilmington_restaurants_with_embeddings.pkl")
df_w.head()
# Out:
#                  business_id  review_stars  \
# 364   W6S482dRQ_9nCcLjfv8VNg             1
# 436   OlOVRlcEstxKK_6hMjy63A             3
# 1103  5IFqqWJTaPNoY2ZgRlX73w             5
# 1298  ixsljpxu56VCTtayIELqUg             3
# 1836  ixsljpxu56VCTtayIELqUg             4
#
#                                                    text  useful  funny  cool  \
# 364   Food was great. But very disappointed with the...       0      0     0
# 436   One of the few diners in North Wilmington, and...       0      0     0
# 1103  My boyfriend and I have lived in trolley squar...       0      0     0
# 1298  I went back here and either I didn't remember ...       0      0     0
# 1836  This is my favorite in Delaware.  The menu is ...       7      0     0
#
#                             name                address        city state  \
# 364   Bawarchi Indian Restaurant      2909 Concord Pike  Wilmington    DE
# 436              Hollywood Grill      1811 Concord Pike  Wilmington    DE
# 1103       Cafe Verdi Restaurant  12A Trolley Sq, Ste A  Wilmington    DE
# 1298                 Tokyo Sushi          3 S Orange St  Wilmington    DE
# 1836                 Tokyo Sushi          3 S Orange St  Wilmington    DE
#
#       review_count  business_stars                    categories  \
# 364            101             3.5  Indian, Chinese, Restaurants
# 436            190             3.5           Restaurants, Diners
# 1103            44             3.0   Restaurants, Italian, Pizza
# 1298            17             3.5       Sushi Bars, Restaurants
# 1836            17             3.5       Sushi Bars, Restaurants
#
#                                               embedding
# 364   [0.04765835404396057, 0.08650010079145432, 0.0...
# 436   [0.10098085552453995, -0.06393218785524368, 0....
# 1103  [-0.04978679120540619, 0.05157990753650665, 0....
# 1298  [-0.008040367625653744, 0.03498610854148865, 0...
# 1836  [-0.045511193573474884, 0.011481113731861115, ...

# %%
# Load CSV created by group

group_csv_path = "C:/Users/User/Desktop/IAT360_Dataset_by_group.csv"
print("Loading dataset...")

our_df = pd.read_csv(group_csv_path)

print(f"Loaded rows: {len(df)}")
our_df.head()
# Out:
# Loading dataset...
# Loaded rows: 60
#               business_id  review_stars  \
# 0  W6S482dRQ_9nCcLjfv8VNg             2
# 1  W6S482dRQ_9nCcLjfv8VNg             1
# 2  25btSWnOGwwB2IQMXF7A-A             5
# 3  25btSWnOGwwB2IQMXF7A-A             5
# 4  5IFqqWJTaPNoY2ZgRlX73w             5
#
#                                                 text  useful  funny  cool  \
# 0  I have been to this location a number of times...       0      0     0
# 1  I'm very disappointed with the food I received...       0      0     0
# 2  I love Trader Joe's. They have THE BEST snacks...       0      0     0
# 3  Nice store with lots of unique finds. Fresh pr...       0      0     0
# 4  The latte art is always impressive and adds a ...       0      0     0
#
#                          name                address        city state  \
# 0  Bawarchi Indian Restaurant      2909 Concord Pike  Wilmington    DE
# 1  Bawarchi Indian Restaurant      2910 Concord Pike  Wilmington    DE
# 2                Trader Joe's      5605 Concord Pike  Wilmington    DE
# 3                Trader Joe's      5605 Concord Pike  Wilmington    DE
# 4       Cafe Verdi Restaurant  12A Trolley Sq, Ste A  Wilmington    DE
#
#    review_count  business_stars  \
# 0             2             3.5
# 1             2             3.5
# 2             2             4.5
# 3             2             4.5
# 4             2             3.0
#
#                                           categories
# 0                       Indian, Chinese, Restaurants
# 1                       Indian, Chinese, Restaurants
# 2  Grocery, Flowers & Gifts, Beer, Wine & Spirits...
# 3  Grocery, Flowers & Gifts, Beer, Wine & Spirits...
# 4                        Restaurants, Italian, Pizza

# %%
# Embedding the review in our csv
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

our_documents = our_df["text"].astype(str).tolist()

our_embeddings = embedding_model.encode(
    our_documents,
    batch_size=64,
    show_progress_bar=True
)

# Attach embeddings to file
our_df["embedding"] = our_embeddings.tolist()


# Save the result

output_path = "IAT360_Dataset_by_group_with_embeddings.pkl"
our_df.to_pickle(output_path)

print(f"Saved dataset with embeddings to: {output_path}")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Saved dataset with embeddings to: IAT360_Dataset_by_group_with_embeddings.pkl

# %%
df_w = pd.read_pickle("IAT360_Dataset_by_group_with_embeddings.pkl")
df_w.head()
# Out:
#               business_id  review_stars  \
# 0  W6S482dRQ_9nCcLjfv8VNg             2
# 1  W6S482dRQ_9nCcLjfv8VNg             1
# 2  25btSWnOGwwB2IQMXF7A-A             5
# 3  25btSWnOGwwB2IQMXF7A-A             5
# 4  5IFqqWJTaPNoY2ZgRlX73w             5
#
#                                                 text  useful  funny  cool  \
# 0  I have been to this location a number of times...       0      0     0
# 1  I'm very disappointed with the food I received...       0      0     0
# 2  I love Trader Joe's. They have THE BEST snacks...       0      0     0
# 3  Nice store with lots of unique finds. Fresh pr...       0      0     0
# 4  The latte art is always impressive and adds a ...       0      0     0
#
#                          name                address        city state  \
# 0  Bawarchi Indian Restaurant      2909 Concord Pike  Wilmington    DE
# 1  Bawarchi Indian Restaurant      2910 Concord Pike  Wilmington    DE
# 2                Trader Joe's      5605 Concord Pike  Wilmington    DE
# 3                Trader Joe's      5605 Concord Pike  Wilmington    DE
# 4       Cafe Verdi Restaurant  12A Trolley Sq, Ste A  Wilmington    DE
#
#    review_count  business_stars  \
# 0             2             3.5
# 1             2             3.5
# 2             2             4.5
# 3             2             4.5
# 4             2             3.0
#
#                                           categories  \
# 0                       Indian, Chinese, Restaurants
# 1                       Indian, Chinese, Restaurants
# 2  Grocery, Flowers & Gifts, Beer, Wine & Spirits...
# 3  Grocery, Flowers & Gifts, Beer, Wine & Spirits...
# 4                        Restaurants, Italian, Pizza
#
#                                            embedding
# 0  [-0.0034387933555990458, -0.011476054787635803...
# 1  [0.013557997532188892, 0.010199910029768944, 0...
# 2  [-0.06484764814376831, 0.031708601862192154, 0...
# 3  [-0.06595531105995178, 0.057717423886060715, 0...
# 4  [-0.04427032545208931, -0.01786855049431324, -...

# %%
embedding_path = "/Users/allycui/Desktop/SFU Fall2025/IAT 360/Group Assignment2/yelp_wilmington_restaurants_with_embeddings.pkl"
df_w = pd.read_pickle(embedding_path)
df_w.head()
# Out:
#                  business_id  review_stars  \
# 364   W6S482dRQ_9nCcLjfv8VNg             1
# 436   OlOVRlcEstxKK_6hMjy63A             3
# 1103  5IFqqWJTaPNoY2ZgRlX73w             5
# 1298  ixsljpxu56VCTtayIELqUg             3
# 1836  ixsljpxu56VCTtayIELqUg             4
#
#                                                    text  useful  funny  cool  \
# 364   Food was great. But very disappointed with the...       0      0     0
# 436   One of the few diners in North Wilmington, and...       0      0     0
# 1103  My boyfriend and I have lived in trolley squar...       0      0     0
# 1298  I went back here and either I didn't remember ...       0      0     0
# 1836  This is my favorite in Delaware.  The menu is ...       7      0     0
#
#                             name                address        city state  \
# 364   Bawarchi Indian Restaurant      2909 Concord Pike  Wilmington    DE
# 436              Hollywood Grill      1811 Concord Pike  Wilmington    DE
# 1103       Cafe Verdi Restaurant  12A Trolley Sq, Ste A  Wilmington    DE
# 1298                 Tokyo Sushi          3 S Orange St  Wilmington    DE
# 1836                 Tokyo Sushi          3 S Orange St  Wilmington    DE
#
#       review_count  business_stars                    categories  \
# 364            101             3.5  Indian, Chinese, Restaurants
# 436            190             3.5           Restaurants, Diners
# 1103            44             3.0   Restaurants, Italian, Pizza
# 1298            17             3.5       Sushi Bars, Restaurants
# 1836            17             3.5       Sushi Bars, Restaurants
#
#                                               embedding
# 364   [0.04765835404396057, 0.08650010079145432, 0.0...
# 436   [0.10098085552453995, -0.06393218785524368, 0....
# 1103  [-0.04978679120540619, 0.05157990753650665, 0....
# 1298  [-0.008040367625653744, 0.03498610854148865, 0...
# 1836  [-0.045511193573474884, 0.011481113731861115, ...

# %%
df = df_w.copy()

df["Document"] = df["text"]          # review text
df["Embedding"] = df["embedding"]    # embedding vector for each review
# quick check
df[["name", "city", "categories", "business_stars", "Document"]].head()
# Out:
#                             name        city                    categories  \
# 364   Bawarchi Indian Restaurant  Wilmington  Indian, Chinese, Restaurants
# 436              Hollywood Grill  Wilmington           Restaurants, Diners
# 1103       Cafe Verdi Restaurant  Wilmington   Restaurants, Italian, Pizza
# 1298                 Tokyo Sushi  Wilmington       Sushi Bars, Restaurants
# 1836                 Tokyo Sushi  Wilmington       Sushi Bars, Restaurants
#
#       business_stars                                           Document
# 364              3.5  Food was great. But very disappointed with the...
# 436              3.5  One of the few diners in North Wilmington, and...
# 1103             3.0  My boyfriend and I have lived in trolley squar...
# 1298             3.5  I went back here and either I didn't remember ...
# 1836             3.5  This is my favorite in Delaware.  The menu is ...

# %%
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
def retrieve_with_pandas(query: str, top_k: int = 5) -> pd.DataFrame:
    query_embedding = embedding_model.encode([query])[0]
    def cosine_sim(vec):
        vec = np.array(vec)
        return float(
            np.dot(query_embedding, vec)
            / (np.linalg.norm(query_embedding) * np.linalg.norm(vec) + 1e-10)
        )
    df_local = df.copy()
    df_local["Similarity"] = df_local["Embedding"].apply(cosine_sim)
    grouped = (
        df_local.sort_values(by="Similarity", ascending=False)
                .groupby("name", as_index=False)
                .first()
    )
    top_restaurants = grouped.sort_values(by="Similarity", ascending=False).head(top_k)
    cols_to_show = [
        "Similarity",
        "name",
        "address",
        "city",
        "business_stars",
        "categories",
        "Document",
    ]
    return top_restaurants[cols_to_show]

# %%
def print_retrieved_restaurants(results: pd.DataFrame):
    for i, (idx, row) in enumerate(results.iterrows()):
        rank = i + 1
        similarity = round(row["Similarity"], 3)
        name = row.get("name", "Unknown name")
        address = row.get("address", "Unknown address")
        city = row.get("city", "Unknown city")
        stars = row.get("business_stars", "N/A")
        categories = row.get("categories", "Unknown categories")
        snippet = str(row["Document"])[:220].replace("\n", " ")

        tag = " (TOP RECOMMENDATION)" if rank == 1 else ""

        print(f"{rank}. {name}{tag} (similarity={similarity}, stars={stars})")
        print(f"   {address}, {city}")
        print(f"   Categories: {categories}")
        print(f"   Review snippet: {snippet}...\n")

# %%
import warnings
warnings.filterwarnings("ignore")

def generate_with_rag(query: str, top_k: int = 3) -> str:
    try:
        retrieved = retrieve_with_pandas(query, top_k=top_k)
    except:
        return "Error: Could not retrieve data."

    ranks = ["🥇 Top recommended", "🥈 Second recommended", "🥉 Third recommended"]

    final_output = ""

    for i in range(len(retrieved)):
        if i >= len(ranks): break

        row = retrieved.iloc[i]
        name = row['name']
        raw_review = str(row['Document'])[:300].replace("\n", " ")

        prompt = (
            f"Review for {name}: \"{raw_review}\"\n"
            f"User Question: {query}\n"
            f"Task: Write one short sentence explaining why {name} is recommended based on the review.\n"
            "Answer:"
        )

        summary = llm(
            prompt,
            max_new_tokens=60,
            temperature=0.1,
            do_sample=True
        )[0]['generated_text']

        final_output += (
            f"{ranks[i]} Restaurant: {name}\n"
            f"Reviews: {summary}\n\n"
        )

    return final_output.strip()

# %% [markdown]
# # Step 3: Testing

# %%
query = "Recommend a good sushi restaurant in Wilmington with high ratings."
results = retrieve_with_pandas(query, top_k=5)
print("USER QUERY:")
print(query)
print("\nTOP MATCHED RESTAURANTS:\n")
print_retrieved_restaurants(results)
# Out:
# USER QUERY:
# Recommend a good sushi restaurant in Wilmington with high ratings.
#
# TOP MATCHED RESTAURANTS:
#
# 1. Le Shio (TOP RECOMMENDATION) (similarity=0.863, stars=3.5)
#    2303 Concord Pike, Wilmington
#    Categories: Restaurants, Asian Fusion
#    Review snippet: So far the best sushi in Wilmington I have tried. The relation between quality and price is great....
#
# 2. Mikimotos Japanese Restaurant & Sushi Bar (similarity=0.852, stars=3.5)
#    1212 N Washington St, Wilmington
#    Categories: Nightlife, Japanese, Sushi Bars, Restaurants, Bars
#    Review snippet: One of my favorite sushi places in the wilmington area.   Sushi was extremely fresh and services was excellent. I highly recommend the chef's choice as it gives you a great variety of sashmi and sushi (69$ for 2). I was ...
#
# 3. Tokyo Sushi (similarity=0.849, stars=3.5)
#    3 S Orange St, Wilmington
#    Categories: Sushi Bars, Restaurants
#    Review snippet: This is my favorite go-to sushi place in the Wilmington area. Good , delicious , clean sushi... They don't have a wide variety. Then again they are a small little place so it is to be expected. Have been buying here for ...
#
# 4. Takumi (similarity=0.833, stars=3.5)
#    1601 Concord Pike, Wilmington
#    Categories: Chinese, Sushi Bars, Japanese, Restaurants
#    Review snippet: Loved this place! Best sushi I ever had. The service and ambiance is great, perfect for a date. Everything is fresh and beautifully played. If you want some great sushi in wilmington that is worth the price I would go he...
#
# 5. Sakura Japanese Sushi Restaurant (similarity=0.821, stars=4.5)
#    1203 Kirkwood Hwy, Wilmington
#    Categories: Sushi Bars, Noodles, Restaurants, Asian Fusion, Japanese
#    Review snippet: I think they have the best sushi in Wilmington/Elsmere area. The price and portion is  more reasonable than other sushi restaurants. Would definitely go back again....

# %% [markdown]
# # Step 4: Testing with self-created dataset

# %%
# load our self-created dataset with embeddings
group_dataset_path = (
    "/Users/allycui/Desktop/SFU Fall2025/"
    "IAT 360/Group Assignment2/IAT360_Dataset_by_group_with_embeddings.pkl"
)

df_group = pd.read_pickle(group_dataset_path)
df_group.head()
# Out:
#               business_id  review_stars  \
# 0  W6S482dRQ_9nCcLjfv8VNg             2
# 1  W6S482dRQ_9nCcLjfv8VNg             1
# 2  25btSWnOGwwB2IQMXF7A-A             5
# 3  25btSWnOGwwB2IQMXF7A-A             5
# 4  5IFqqWJTaPNoY2ZgRlX73w             5
#
#                                                 text  useful  funny  cool  \
# 0  I have been to this location a number of times...       0      0     0
# 1  I'm very disappointed with the food I received...       0      0     0
# 2  I love Trader Joe's. They have THE BEST snacks...       0      0     0
# 3  Nice store with lots of unique finds. Fresh pr...       0      0     0
# 4  The latte art is always impressive and adds a ...       0      0     0
#
#                          name                address        city state  \
# 0  Bawarchi Indian Restaurant      2909 Concord Pike  Wilmington    DE
# 1  Bawarchi Indian Restaurant      2910 Concord Pike  Wilmington    DE
# 2                Trader Joe's      5605 Concord Pike  Wilmington    DE
# 3                Trader Joe's      5605 Concord Pike  Wilmington    DE
# 4       Cafe Verdi Restaurant  12A Trolley Sq, Ste A  Wilmington    DE
#
#    review_count  business_stars  \
# 0             2             3.5
# 1             2             3.5
# 2             2             4.5
# 3             2             4.5
# 4             2             3.0
#
#                                           categories  \
# 0                       Indian, Chinese, Restaurants
# 1                       Indian, Chinese, Restaurants
# 2  Grocery, Flowers & Gifts, Beer, Wine & Spirits...
# 3  Grocery, Flowers & Gifts, Beer, Wine & Spirits...
# 4                        Restaurants, Italian, Pizza
#
#                                            embedding
# 0  [-0.0034387933555990458, -0.011476054787635803...
# 1  [0.013557997532188892, 0.010199910029768944, 0...
# 2  [-0.06484764814376831, 0.031708601862192154, 0...
# 3  [-0.06595531105995178, 0.057717423886060715, 0...
# 4  [-0.04427032545208931, -0.01786855049431324, -...

# %%
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
emb_matrix_group = np.vstack(df_group["embedding"].values)
_EPS = 1e-10

def embed_query(query: str) -> np.ndarray:
    return embedding_model.encode([query])[0]

def retrieve_from_group_df(query: str, top_k: int = 5) -> pd.DataFrame:
    q_emb = embed_query(query)
    dot_products = emb_matrix_group @ q_emb
    norms = np.linalg.norm(emb_matrix_group, axis=1) * (np.linalg.norm(q_emb) + _EPS)
    similarities = dot_products / (norms + _EPS)

    top_idx = np.argsort(similarities)[::-1][:top_k]
    top_scores = similarities[top_idx]

    results = df_group.iloc[top_idx].copy()
    results["similarity"] = top_scores
    return results

# %%
#self-created test set for our group dataset

test_cases = [
    # 1. Sushi – Tokyo Sushi or Sakura Japanese Restaurant
    {
        "query": "Recommend a good sushi restaurant in Wilmington with high ratings.",
        "expected_name_keywords": ["tokyo", "sakura"]
    },

    # 2. Indian – Bawarchi Indian Restaurant
    {
        "query": "I want authentic Indian food in Wilmington.",
        "expected_name_keywords": ["bawarchi"]
    },

    # 3. Mexican – Taqueria Los Primos or QDOBA Mexican Eats
    {
        "query": "Suggest a casual Mexican restaurant with tasty food for dinner.",
        "expected_name_keywords": ["primos", "qdoba"]
    },

    # 4. Cozy Italian date night – Ristorante Attilio, Piccolina Toscana, Mona Lisa, Cafe Napoli
    {
        "query": "Recommend a cozy Italian restaurant for a date night in Wilmington.",
        "expected_name_keywords": ["attilio", "toscan", "mona", "napoli"]
    },

    # 5. Pizza – Ciao's Trolley Pizza & Grill, Season's Pizza, Grotto Pizza, Pizza Hut
    {
        "query": "Where can I get good pizza in Wilmington?",
        "expected_name_keywords": ["ciao", "season", "grotto", "pizza hut"]
    },

    # 6. Brunch / breakfast – Eeffoc Cafe, Maryland Avenue Sub Shop, Russell's Quality Food
    {
        "query": "Recommend a place for a good breakfast or brunch with hearty portions.",
        "expected_name_keywords": ["eeffoc", "maryland", "russell"]
    },

    # 7. Cheap and quick – Subway, Little Caesars Pizza, QDOBA Mexican Eats
    {
        "query": "Find a cheap and quick place to grab a meal in Wilmington.",
        "expected_name_keywords": ["subway", "little caesars", "qdoba"]
    },

    # 8. Wings / sports bar – Buffalo Wild Wings, Chili's
    {
        "query": "I want a place with chicken wings to watch a game.",
        "expected_name_keywords": ["buffalo wild", "chili"]
    },

    # 9. Steakhouse – Walter's Steakhouse
    {
        "query": "Recommend a nice steakhouse in Wilmington for a special occasion.",
        "expected_name_keywords": ["walter"]
    },

    # 10. Asian fusion / Vietnamese – Bubble Shack, 8th & Union Kitchen
    {
        "query": "Suggest an Asian fusion or Vietnamese restaurant in Wilmington.",
        "expected_name_keywords": ["bubble", "union"]
    },

    # 11. Grocery / food store – Trader Joe's
    {
        "query": "Is there a grocery store with good food options in Wilmington?",
        "expected_name_keywords": ["trader joe"]
    },

    # 12. American diner / comfort – Mary's Kountry Kitchen, Red Robin
    {
        "query": "Recommend a casual American restaurant or diner with comfort food.",
        "expected_name_keywords": ["mary", "red robin"]
    },
]

test_df = pd.DataFrame(test_cases)
test_df
# Out:
#                                                 query  \
# 0   Recommend a good sushi restaurant in Wilmingto...
# 1         I want authentic Indian food in Wilmington.
# 2   Suggest a casual Mexican restaurant with tasty...
# 3   Recommend a cozy Italian restaurant for a date...
# 4           Where can I get good pizza in Wilmington?
# 5   Recommend a place for a good breakfast or brun...
# 6   Find a cheap and quick place to grab a meal in...
# 7   I want a place with chicken wings to watch a g...
# 8   Recommend a nice steakhouse in Wilmington for ...
# 9   Suggest an Asian fusion or Vietnamese restaura...
# 10  Is there a grocery store with good food option...
# 11  Recommend a casual American restaurant or dine...
#
#                expected_name_keywords
# 0                     [tokyo, sakura]
# 1                          [bawarchi]
# 2                     [primos, qdoba]
# 3     [attilio, toscan, mona, napoli]
# 4   [ciao, season, grotto, pizza hut]
# 5         [eeffoc, maryland, russell]
# 6     [subway, little caesars, qdoba]
# 7               [buffalo wild, chili]
# 8                            [walter]
# 9                     [bubble, union]
# 10                       [trader joe]
# 11                  [mary, red robin]

# %%
def evaluate_testset(df_group, test_df, top_k: int = 5):
    total = len(test_df)
    hits = 0
    detailed_rows = []

    for idx, row in test_df.iterrows():
        query = row["query"]
        expected_raw = row["expected_name_keywords"]

        if isinstance(expected_raw, str):
            expected_keywords = [expected_raw.lower()]
        else:
            expected_keywords = [e.lower() for e in expected_raw]

        retrieved = retrieve_from_group_df(query, top_k=top_k)
        retrieved_names = [str(n).lower() for n in retrieved["name"].tolist()]

        hit = any(
            any(exp_kw in name for name in retrieved_names)
            for exp_kw in expected_keywords
        )
        hits += int(hit)

        detailed_rows.append({
            "query": query,
            "expected_keywords": expected_keywords,
            "retrieved_names": retrieved["name"].tolist(),
            f"hit@{top_k}": hit
        })

    hit_rate = hits / total if total > 0 else 0.0
    detailed_df = pd.DataFrame(detailed_rows)
    return hit_rate, detailed_df

# %%
top_k = 5
hit_rate, detailed_results = evaluate_testset(df_group, test_df, top_k=top_k)

print(f"Hit-rate@{top_k}: {hit_rate:.2f}  (i.e., {hit_rate*100:.1f}%)")
detailed_results
# Out:
# Hit-rate@5: 0.75  (i.e., 75.0%)
#                                                 query  \
# 0   Recommend a good sushi restaurant in Wilmingto...
# 1         I want authentic Indian food in Wilmington.
# 2   Suggest a casual Mexican restaurant with tasty...
# 3   Recommend a cozy Italian restaurant for a date...
# 4           Where can I get good pizza in Wilmington?
# 5   Recommend a place for a good breakfast or brun...
# 6   Find a cheap and quick place to grab a meal in...
# 7   I want a place with chicken wings to watch a g...
# 8   Recommend a nice steakhouse in Wilmington for ...
# 9   Suggest an Asian fusion or Vietnamese restaura...
# 10  Is there a grocery store with good food option...
# 11  Recommend a casual American restaurant or dine...
#
#                     expected_keywords  \
# 0                     [tokyo, sakura]
# 1                          [bawarchi]
# 2                     [primos, qdoba]
# 3     [attilio, toscan, mona, napoli]
# 4   [ciao, season, grotto, pizza hut]
# 5         [eeffoc, maryland, russell]
# 6     [subway, little caesars, qdoba]
# 7               [buffalo wild, chili]
# 8                            [walter]
# 9                     [bubble, union]
# 10                       [trader joe]
# 11                  [mary, red robin]
#
#                                       retrieved_names  hit@5
# 0   [Sakura Japanese Restaurant, Tokyo Sushi, Saku...   True
# 1   [Mary's Kountry Kitchen, Russell's Quality Foo...  False
# 2   [QDOBA Mexican Eats, Cafe Napoli Restaurant & ...   True
# 3   [Mona Lisa, Mary's Kountry Kitchen, Cafe Napol...   True
# 4   [Mary's Kountry Kitchen, Grotto Pizza, Pizza H...   True
# 5   [Mona Lisa, Season's Pizza, QDOBA Mexican Eats...  False
# 6   [Mary's Kountry Kitchen, Russell's Quality Foo...   True
# 7   [Buffalo Wild Wings, Buffalo Wild Wings, Piree...   True
# 8   [Mary's Kountry Kitchen, Walter's Steakhouse, ...   True
# 9   [Mary's Kountry Kitchen, Mona Lisa, Russell's ...   True
# 10  [Mary's Kountry Kitchen, QDOBA Mexican Eats, T...   True
# 11  [Mona Lisa, Season's Pizza, QDOBA Mexican Eats...  False

# %% [markdown]
# # Step 4: Compare the Results

# %%
query = "Recommend a good sushi restaurant in Wilmington with high ratings."

# without rag
print("\n[ANSWER WITHOUT RAG:]\n")
no_rag_response = llm(
    query,
    max_new_tokens=100,
    do_sample=True,
    repetition_penalty=1.2
)[0]["generated_text"]
print(no_rag_response)

# with rag
print("\n\n[ANSWER WITH RAG:]\n")
rag_response = generate_with_rag(query, top_k=3)
print(rag_response)
# Out:
# [ANSWER WITHOUT RAG:]
#
# Great sushi, very good prices, good service, and a great atmosphere. I'd recommend this place to anyone who loves sushi.
#
#
# [ANSWER WITH RAG:]
#
# 🥇 Top recommended Restaurant: Le Shio
# Reviews: Le Shio is a good sushi restaurant in Wilmington with high ratings.
#
# 🥈 Second recommended Restaurant: Mikimotos Japanese Restaurant & Sushi Bar
# Reviews: Mikimotos Japanese Restaurant & Sushi Bar is one of my favorite sushi places in the wilmington area. Sushi was extremely fresh and services was excellent. I highly recommend the chef's choice as it gives you a great variety of sashmi and
#
# 🥉 Third recommended Restaurant: Tokyo Sushi
# Reviews: Tokyo Sushi is my favorite go-to sushi restaurant in the Wilmington area. Good , delicious , clean sushi... They don't have a wide variety. Then again they are a small little place so it is to be expected. Have been buying here for years .

# %% [markdown]
# # Mock-Up Chatbot

# %%
print("RESTAURANT BOT IS READY! (Type 'quit' to stop)")

while True:
    user_input = input("\nUser Query: ")

    if user_input.lower() in ["quit", "exit", "stop"]:
        print("Goodbye!")
        break

    print("Thinking...")
    try:
        answer = generate_with_rag(user_input, top_k=3)

        print("\n" + "="*40)
        print(f"Bot Answer:\n{answer}")
        print("="*40)
    except Exception as e:
        print(f"Error: {e}")
# Out:
# RESTAURANT BOT IS READY! (Type 'quit' to stop)
#
# User Query: Any recommend pizza Restaurant?
# Thinking...
#
# ========================================
# Bot Answer:
# 🥇 Top recommended Restaurant: La Pizzeria Metro
# Reviews: If you're tired of the same old pizza I highly recommend this restaurant. Last night my wife and I had the wings and the Bianco Bruchetta Pizza; out of this world. There is plenty of parking at this restaurant and it has an expensive ambiance, but the prices are
#
# 🥈 Second recommended Restaurant: Cafe Napoli Restaurant & Pizzeria
# Reviews: The food is pretty good, but the pizza is sub-par to a place like Ciaos. The atmosphere is nice if you sit in the dining area and the service is average. I wasn't all that impressed but it was an ok place to go. The prices
#
# 🥉 Third recommended Restaurant: Oscar's Famous Pizzeria
# Reviews: Oscar's Famous Pizzeria is a good pizza place.
# ========================================
#
# User Query: quit
# Goodbye!

# %% [markdown]
# # Chatbot Deployment

# %%
# !pip3 install gradio -q
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
import gradio as gr

# %%
def chatbot_interface(user_query):
    return generate_with_rag(user_query, top_k=3)

demo = gr.Interface(
    fn=chatbot_interface,
    inputs=gr.Textbox(label="Ask about Wilmington Restaurants", placeholder="e.g., Best sushi place?"),
    outputs=gr.Textbox(label="Bot Recommendation", lines=10),
    title="🍔 Wilmington Foodie Bot",
    description="A RAG-based restaurant recommender using Flan-T5 and Yelp data."
)

try:
    print("🚀 Launching Chatbot... (Click the link below)")
    demo.launch(share=True, debug=True)
except KeyboardInterrupt:
    print("\nChatbot stopped by user. Goodbye!")
    demo.close()
# Out:
# 🚀 Launching Chatbot... (Click the link below)
# * Running on local URL:  http://127.0.0.1:7861
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# * Running on public URL: https://8e28e8e50a066cf151.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8e28e8e50a066cf151.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
#
# Chatbot stopped by user. Goodbye!
# Closing server running on port: 7861
